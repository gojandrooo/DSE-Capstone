# %%
# import sqlalchemy as sal
# engine = sal.create_engine('postgresql+psycopg2://ag_class:WUcgdfQ1@awesome-hw.sdsc.edu/postgres')
# conn = engine.connect()

# %%
import sqlalchemy as sal

#username : postgres
#password: welcome123
#db end point: dse260-grp7-pgdb.c24gvnrvah5h.us-west-2.rds.amazonaws.com
#db name: staging_db
 
engine = sal.create_engine('postgresql+psycopg2://postgres:welcome123\
@dse260-grp7-pgdb.c24gvnrvah5h.us-west-2.rds.amazonaws.com/staging_db')
conn = engine.connect()

# %%
some_var = 'gah'

print(f'{some_var} is show')
# Out:
# gah is show

# %%
# import sqlalchemy as sal

# username = 'postgres'
# dialect = 'psycopg2'
# password = 'welcome123'
# db_end_point: 'dse260-grp7-pgdb.c24gvnrvah5h.us-west-2.rds.amazonaws.com'
# db_name: 'staging_db'
 
# engine = sal.create_engine(f'{username}+{dialect}://postgres:welcome123\
# @dse260-grp7-pgdb.c24gvnrvah5h.us-west-2.rds.amazonaws.com/staging_db')
# conn = engine.connect()

# %%
engine
# Out:
# Engine(postgresql+psycopg2://postgres:***@dse260-grp7-pgdb.c24gvnrvah5h.us-west-2.rds.amazonaws.com/staging_db)

# %%
"""
created a table manually in postgres db to query and test the connection 
if below block returns records , that means connection is succesfull
"""
from sqlalchemy import text 
sqlquery1 = text("select * from test_table")
result = conn.execute(sqlquery1)
data = [i for i in result]
print('records queried from postgres =',len(data))
# Out:
# records queried from postgres = 2

# %%
"""
below snippet copies the pandas dataframe
to test_tbl ( table name ) as mentioned in the to_sql command
"""
import pandas as pd
df = pd.DataFrame({'co11':['a','b'],'col2':['c','d']})
df
df.to_sql('test_table',engine)
# Out:
#   co11 col2
# 0    a    c
# 1    b    d

# %% [markdown]
# <h1>How to connect to postgres from PgAdmin<h1>

# %% [markdown]
# ![Screen Shot 2023-02-18 at 12.32.50 PM.png](attachment:d3568e08-8ef0-41f7-ac94-23fb3c873c49.png)

# %% [markdown]
# ![Screen Shot 2023-02-18 at 12.33.15 PM.png](attachment:d35f8ed4-9ec0-45e7-9428-b1d06adeb7ee.png)
