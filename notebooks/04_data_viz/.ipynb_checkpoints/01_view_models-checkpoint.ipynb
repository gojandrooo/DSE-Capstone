# %%
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-darkgrid')
import seaborn as sns

# %%
#intialize values
seed=27
data_dir = '../../data/'
model_dir = '../../app/model/'

# open the parameters json
file_path = "model_parameters.json"
with open(model_dir + file_path) as model_params:
    model_params = json.load(model_params)

models = list(model_params.keys())
# sorted(models)


#
#create df with all keys(ignoreing performance summary as it is nested)
#

base_dict = {}
final_dict = {}
ignore_list = 'performance_sumamry'
i=0;
for k in model_params:
    base_dict={}
    for k2 in model_params[k]:
        if k2 not in 'performance_summary':
            base_dict[k2]=model_params[k][k2]        
        final_dict[k]=base_dict

df = pd.DataFrame.from_dict(final_dict,orient='index')

#
#create a new df with the performance summary alone
#

psummary_dict = {}
for k in model_params:
    psummary_dict[k] = model_params[k]['performance_summary']

psummary_df = pd.DataFrame.from_dict(psummary_dict,orient='index')    

# join the 2 df's
final_df = df.join(psummary_df)

#select the cols with numeric values only to compare metrics ( so exclude features and weights )
summary_cols = [x for x in final_df.columns if x not in ['features','weights']]

#print and check the df
performance_df = final_df[summary_cols].sort_index()
performance_df
# Out:
#                                                hidden_size      lr  \
# OneLayer_1000_epochs_optimized_recall_score             10  0.0001
# OneLayer_100_epochs_optimized_roc_auc_score            500  0.0100
# OneLayer_250_epochs_optimized_roc_auc_score            500  0.0100
# OneLayer_500_epochs_optimized_roc_auc_score            250  0.0100
# OneLayer_750_epochs_optimized_roc_auc_score            250  0.0100
# ThreeLayer_1000_epochs_optimized_recall_score           10  0.0001
# ThreeLayer_100_epochs_optimized_f1_score               250  0.0100
# ThreeLayer_250_epochs_optimized_f1_score               250  0.0100
# ThreeLayer_250_epochs_optimized_roc_auc_score          100  0.0100
# ThreeLayer_500_epochs_optimized_roc_auc_score          250  0.0100
# ThreeLayer_750_epochs_optimized_roc_auc_score          100  0.0100
# TwoLayer_1000_epochs_optimized_f1_score                250  0.0100
# TwoLayer_100_epochs_optimized_roc_auc_score            500  0.0100
# TwoLayer_250_epochs_optimized_recall_score              10  0.0001
# TwoLayer_250_epochs_optimized_roc_auc_score            250  0.0100
# TwoLayer_500_epochs_optimized_recall_score              10  0.0001
# TwoLayer_500_epochs_optimized_roc_auc_score            500  0.0100
# TwoLayer_750_epochs_optimized_recall_score             100  0.0100
# TwoLayer_750_epochs_optimized_roc_auc_score            100  0.0100
#
#                                                dropout_rate  epochs  \
# OneLayer_1000_epochs_optimized_recall_score            0.20    1000
# OneLayer_100_epochs_optimized_roc_auc_score            0.05     100
# OneLayer_250_epochs_optimized_roc_auc_score            0.15     250
# OneLayer_500_epochs_optimized_roc_auc_score            0.20     500
# OneLayer_750_epochs_optimized_roc_auc_score            0.15     750
# ThreeLayer_1000_epochs_optimized_recall_score          0.20    1000
# ThreeLayer_100_epochs_optimized_f1_score               0.10     100
# ThreeLayer_250_epochs_optimized_f1_score               0.05     250
# ThreeLayer_250_epochs_optimized_roc_auc_score          0.15     250
# ThreeLayer_500_epochs_optimized_roc_auc_score          0.05     500
# ThreeLayer_750_epochs_optimized_roc_auc_score          0.20     750
# TwoLayer_1000_epochs_optimized_f1_score                0.10    1000
# TwoLayer_100_epochs_optimized_roc_auc_score            0.05     100
# TwoLayer_250_epochs_optimized_recall_score             0.05     250
# TwoLayer_250_epochs_optimized_roc_auc_score            0.20     250
# TwoLayer_500_epochs_optimized_recall_score             0.15     500
# TwoLayer_500_epochs_optimized_roc_auc_score            0.10     500
# TwoLayer_750_epochs_optimized_recall_score             0.05     750
# TwoLayer_750_epochs_optimized_roc_auc_score            0.20     750
#
#                                               model_class grid_search_metric  \
# OneLayer_1000_epochs_optimized_recall_score      OneLayer       recall_score
# OneLayer_100_epochs_optimized_roc_auc_score      OneLayer      roc_auc_score
# OneLayer_250_epochs_optimized_roc_auc_score      OneLayer      roc_auc_score
# OneLayer_500_epochs_optimized_roc_auc_score      OneLayer      roc_auc_score
# OneLayer_750_epochs_optimized_roc_auc_score      OneLayer      roc_auc_score
# ThreeLayer_1000_epochs_optimized_recall_score  ThreeLayer       recall_score
# ThreeLayer_100_epochs_optimized_f1_score       ThreeLayer           f1_score
# ThreeLayer_250_epochs_optimized_f1_score       ThreeLayer           f1_score
# ThreeLayer_250_epochs_optimized_roc_auc_score  ThreeLayer      roc_auc_score
# ThreeLayer_500_epochs_optimized_roc_auc_score  ThreeLayer      roc_auc_score
# ThreeLayer_750_epochs_optimized_roc_auc_score  ThreeLayer      roc_auc_score
# TwoLayer_1000_epochs_optimized_f1_score          TwoLayer           f1_score
# TwoLayer_100_epochs_optimized_roc_auc_score      TwoLayer      roc_auc_score
# TwoLayer_250_epochs_optimized_recall_score       TwoLayer       recall_score
# TwoLayer_250_epochs_optimized_roc_auc_score      TwoLayer      roc_auc_score
# TwoLayer_500_epochs_optimized_recall_score       TwoLayer       recall_score
# TwoLayer_500_epochs_optimized_roc_auc_score      TwoLayer      roc_auc_score
# TwoLayer_750_epochs_optimized_recall_score       TwoLayer       recall_score
# TwoLayer_750_epochs_optimized_roc_auc_score      TwoLayer      roc_auc_score
#
#                                                train_loss  val_loss  \
# OneLayer_1000_epochs_optimized_recall_score      0.494871  0.504961
# OneLayer_100_epochs_optimized_roc_auc_score      0.160787  0.436307
# OneLayer_250_epochs_optimized_roc_auc_score      0.109946  0.514772
# OneLayer_500_epochs_optimized_roc_auc_score      0.105076  0.518428
# OneLayer_750_epochs_optimized_roc_auc_score      0.122015  0.437214
# ThreeLayer_1000_epochs_optimized_recall_score    0.465518  0.456387
# ThreeLayer_100_epochs_optimized_f1_score         0.095807  0.708236
# ThreeLayer_250_epochs_optimized_f1_score         0.019344  2.105474
# ThreeLayer_250_epochs_optimized_roc_auc_score    0.042090  1.142197
# ThreeLayer_500_epochs_optimized_roc_auc_score    0.020326  1.864025
# ThreeLayer_750_epochs_optimized_roc_auc_score    0.017023  1.279547
# TwoLayer_1000_epochs_optimized_f1_score          0.007723  3.221979
# TwoLayer_100_epochs_optimized_roc_auc_score      0.144660  0.715845
# TwoLayer_250_epochs_optimized_recall_score       0.506930  0.470136
# TwoLayer_250_epochs_optimized_roc_auc_score      0.110065  0.752571
# TwoLayer_500_epochs_optimized_recall_score       0.517934  0.477946
# TwoLayer_500_epochs_optimized_roc_auc_score      0.018919  2.052340
# TwoLayer_750_epochs_optimized_recall_score       0.011799  2.162801
# TwoLayer_750_epochs_optimized_roc_auc_score      0.032548  0.807868
#
#                                                train_accuracy  test_accuracy  \
# OneLayer_1000_epochs_optimized_recall_score          0.773490       0.745387
# OneLayer_100_epochs_optimized_roc_auc_score          0.936242       0.856089
# OneLayer_250_epochs_optimized_roc_auc_score          0.959732       0.845018
# OneLayer_500_epochs_optimized_roc_auc_score          0.961409       0.845018
# OneLayer_750_epochs_optimized_roc_auc_score          0.952181       0.870849
# ThreeLayer_1000_epochs_optimized_recall_score        0.786074       0.797048
# ThreeLayer_100_epochs_optimized_f1_score             0.958893       0.837638
# ThreeLayer_250_epochs_optimized_f1_score             0.994966       0.859779
# ThreeLayer_250_epochs_optimized_roc_auc_score        0.989094       0.852399
# ThreeLayer_500_epochs_optimized_roc_auc_score        0.991611       0.885609
# ThreeLayer_750_epochs_optimized_roc_auc_score        0.993289       0.867159
# TwoLayer_1000_epochs_optimized_f1_score              0.994966       0.870849
# TwoLayer_100_epochs_optimized_roc_auc_score          0.939597       0.867159
# TwoLayer_250_epochs_optimized_recall_score           0.786074       0.797048
# TwoLayer_250_epochs_optimized_roc_auc_score          0.950503       0.874539
# TwoLayer_500_epochs_optimized_recall_score           0.791107       0.797048
# TwoLayer_500_epochs_optimized_roc_auc_score          0.992450       0.863469
# TwoLayer_750_epochs_optimized_recall_score           0.994966       0.863469
# TwoLayer_750_epochs_optimized_roc_auc_score          0.989933       0.859779
#
#                                                test_precision  test_recall  \
# OneLayer_1000_epochs_optimized_recall_score          0.208333     0.090909
# OneLayer_100_epochs_optimized_roc_auc_score          0.642857     0.654545
# OneLayer_250_epochs_optimized_roc_auc_score          0.627451     0.581818
# OneLayer_500_epochs_optimized_roc_auc_score          0.627451     0.581818
# OneLayer_750_epochs_optimized_roc_auc_score          0.708333     0.618182
# ThreeLayer_1000_epochs_optimized_recall_score        0.000000     0.000000
# ThreeLayer_100_epochs_optimized_f1_score             0.603774     0.581818
# ThreeLayer_250_epochs_optimized_f1_score             0.666667     0.618182
# ThreeLayer_250_epochs_optimized_roc_auc_score        0.647059     0.600000
# ThreeLayer_500_epochs_optimized_roc_auc_score        0.722222     0.709091
# ThreeLayer_750_epochs_optimized_roc_auc_score        0.693878     0.618182
# TwoLayer_1000_epochs_optimized_f1_score              0.685185     0.672727
# TwoLayer_100_epochs_optimized_roc_auc_score          0.679245     0.654545
# TwoLayer_250_epochs_optimized_recall_score           0.000000     0.000000
# TwoLayer_250_epochs_optimized_roc_auc_score          0.714286     0.636364
# TwoLayer_500_epochs_optimized_recall_score           0.500000     0.054545
# TwoLayer_500_epochs_optimized_roc_auc_score          0.680000     0.618182
# TwoLayer_750_epochs_optimized_recall_score           0.645161     0.727273
# TwoLayer_750_epochs_optimized_roc_auc_score          0.666667     0.618182
#
#                                                test_f1_score  test_auc
# OneLayer_1000_epochs_optimized_recall_score         0.126582  0.729209
# OneLayer_100_epochs_optimized_roc_auc_score         0.648649  0.884933
# OneLayer_250_epochs_optimized_roc_auc_score         0.603774  0.892677
# OneLayer_500_epochs_optimized_roc_auc_score         0.603774  0.900253
# OneLayer_750_epochs_optimized_roc_auc_score         0.660194  0.909259
# ThreeLayer_1000_epochs_optimized_recall_score       0.000000  0.795034
# ThreeLayer_100_epochs_optimized_f1_score            0.592593  0.869613
# ThreeLayer_250_epochs_optimized_f1_score            0.641509  0.896002
# ThreeLayer_250_epochs_optimized_roc_auc_score       0.622642  0.896128
# ThreeLayer_500_epochs_optimized_roc_auc_score       0.715596  0.922685
# ThreeLayer_750_epochs_optimized_roc_auc_score       0.653846  0.911406
# TwoLayer_1000_epochs_optimized_f1_score             0.678899  0.889941
# TwoLayer_100_epochs_optimized_roc_auc_score         0.666667  0.912879
# TwoLayer_250_epochs_optimized_recall_score          0.000000  0.722938
# TwoLayer_250_epochs_optimized_roc_auc_score         0.673077  0.921675
# TwoLayer_500_epochs_optimized_recall_score          0.098361  0.795118
# TwoLayer_500_epochs_optimized_roc_auc_score         0.647619  0.894697
# TwoLayer_750_epochs_optimized_recall_score          0.683761  0.884175
# TwoLayer_750_epochs_optimized_roc_auc_score         0.641509  0.913636

# %%
metrics = [
    'test_accuracy',
    'test_precision',
    'test_recall',
    'test_f1_score',
    'test_auc'
]
idx = 4
print(metrics[idx])

performance_df.sort_values(by=metrics[idx], ascending=False)
# Out:
# test_auc
#                                                hidden_size      lr  \
# ThreeLayer_500_epochs_optimized_roc_auc_score          250  0.0100
# TwoLayer_250_epochs_optimized_roc_auc_score            250  0.0100
# TwoLayer_750_epochs_optimized_roc_auc_score            100  0.0100
# TwoLayer_100_epochs_optimized_roc_auc_score            500  0.0100
# ThreeLayer_750_epochs_optimized_roc_auc_score          100  0.0100
# OneLayer_750_epochs_optimized_roc_auc_score            250  0.0100
# OneLayer_500_epochs_optimized_roc_auc_score            250  0.0100
# ThreeLayer_250_epochs_optimized_roc_auc_score          100  0.0100
# ThreeLayer_250_epochs_optimized_f1_score               250  0.0100
# TwoLayer_500_epochs_optimized_roc_auc_score            500  0.0100
# OneLayer_250_epochs_optimized_roc_auc_score            500  0.0100
# TwoLayer_1000_epochs_optimized_f1_score                250  0.0100
# OneLayer_100_epochs_optimized_roc_auc_score            500  0.0100
# TwoLayer_750_epochs_optimized_recall_score             100  0.0100
# ThreeLayer_100_epochs_optimized_f1_score               250  0.0100
# TwoLayer_500_epochs_optimized_recall_score              10  0.0001
# ThreeLayer_1000_epochs_optimized_recall_score           10  0.0001
# OneLayer_1000_epochs_optimized_recall_score             10  0.0001
# TwoLayer_250_epochs_optimized_recall_score              10  0.0001
#
#                                                dropout_rate  epochs  \
# ThreeLayer_500_epochs_optimized_roc_auc_score          0.05     500
# TwoLayer_250_epochs_optimized_roc_auc_score            0.20     250
# TwoLayer_750_epochs_optimized_roc_auc_score            0.20     750
# TwoLayer_100_epochs_optimized_roc_auc_score            0.05     100
# ThreeLayer_750_epochs_optimized_roc_auc_score          0.20     750
# OneLayer_750_epochs_optimized_roc_auc_score            0.15     750
# OneLayer_500_epochs_optimized_roc_auc_score            0.20     500
# ThreeLayer_250_epochs_optimized_roc_auc_score          0.15     250
# ThreeLayer_250_epochs_optimized_f1_score               0.05     250
# TwoLayer_500_epochs_optimized_roc_auc_score            0.10     500
# OneLayer_250_epochs_optimized_roc_auc_score            0.15     250
# TwoLayer_1000_epochs_optimized_f1_score                0.10    1000
# OneLayer_100_epochs_optimized_roc_auc_score            0.05     100
# TwoLayer_750_epochs_optimized_recall_score             0.05     750
# ThreeLayer_100_epochs_optimized_f1_score               0.10     100
# TwoLayer_500_epochs_optimized_recall_score             0.15     500
# ThreeLayer_1000_epochs_optimized_recall_score          0.20    1000
# OneLayer_1000_epochs_optimized_recall_score            0.20    1000
# TwoLayer_250_epochs_optimized_recall_score             0.05     250
#
#                                               model_class grid_search_metric  \
# ThreeLayer_500_epochs_optimized_roc_auc_score  ThreeLayer      roc_auc_score
# TwoLayer_250_epochs_optimized_roc_auc_score      TwoLayer      roc_auc_score
# TwoLayer_750_epochs_optimized_roc_auc_score      TwoLayer      roc_auc_score
# TwoLayer_100_epochs_optimized_roc_auc_score      TwoLayer      roc_auc_score
# ThreeLayer_750_epochs_optimized_roc_auc_score  ThreeLayer      roc_auc_score
# OneLayer_750_epochs_optimized_roc_auc_score      OneLayer      roc_auc_score
# OneLayer_500_epochs_optimized_roc_auc_score      OneLayer      roc_auc_score
# ThreeLayer_250_epochs_optimized_roc_auc_score  ThreeLayer      roc_auc_score
# ThreeLayer_250_epochs_optimized_f1_score       ThreeLayer           f1_score
# TwoLayer_500_epochs_optimized_roc_auc_score      TwoLayer      roc_auc_score
# OneLayer_250_epochs_optimized_roc_auc_score      OneLayer      roc_auc_score
# TwoLayer_1000_epochs_optimized_f1_score          TwoLayer           f1_score
# OneLayer_100_epochs_optimized_roc_auc_score      OneLayer      roc_auc_score
# TwoLayer_750_epochs_optimized_recall_score       TwoLayer       recall_score
# ThreeLayer_100_epochs_optimized_f1_score       ThreeLayer           f1_score
# TwoLayer_500_epochs_optimized_recall_score       TwoLayer       recall_score
# ThreeLayer_1000_epochs_optimized_recall_score  ThreeLayer       recall_score
# OneLayer_1000_epochs_optimized_recall_score      OneLayer       recall_score
# TwoLayer_250_epochs_optimized_recall_score       TwoLayer       recall_score
#
#                                                train_loss  val_loss  \
# ThreeLayer_500_epochs_optimized_roc_auc_score    0.020326  1.864025
# TwoLayer_250_epochs_optimized_roc_auc_score      0.110065  0.752571
# TwoLayer_750_epochs_optimized_roc_auc_score      0.032548  0.807868
# TwoLayer_100_epochs_optimized_roc_auc_score      0.144660  0.715845
# ThreeLayer_750_epochs_optimized_roc_auc_score    0.017023  1.279547
# OneLayer_750_epochs_optimized_roc_auc_score      0.122015  0.437214
# OneLayer_500_epochs_optimized_roc_auc_score      0.105076  0.518428
# ThreeLayer_250_epochs_optimized_roc_auc_score    0.042090  1.142197
# ThreeLayer_250_epochs_optimized_f1_score         0.019344  2.105474
# TwoLayer_500_epochs_optimized_roc_auc_score      0.018919  2.052340
# OneLayer_250_epochs_optimized_roc_auc_score      0.109946  0.514772
# TwoLayer_1000_epochs_optimized_f1_score          0.007723  3.221979
# OneLayer_100_epochs_optimized_roc_auc_score      0.160787  0.436307
# TwoLayer_750_epochs_optimized_recall_score       0.011799  2.162801
# ThreeLayer_100_epochs_optimized_f1_score         0.095807  0.708236
# TwoLayer_500_epochs_optimized_recall_score       0.517934  0.477946
# ThreeLayer_1000_epochs_optimized_recall_score    0.465518  0.456387
# OneLayer_1000_epochs_optimized_recall_score      0.494871  0.504961
# TwoLayer_250_epochs_optimized_recall_score       0.506930  0.470136
#
#                                                train_accuracy  test_accuracy  \
# ThreeLayer_500_epochs_optimized_roc_auc_score        0.991611       0.885609
# TwoLayer_250_epochs_optimized_roc_auc_score          0.950503       0.874539
# TwoLayer_750_epochs_optimized_roc_auc_score          0.989933       0.859779
# TwoLayer_100_epochs_optimized_roc_auc_score          0.939597       0.867159
# ThreeLayer_750_epochs_optimized_roc_auc_score        0.993289       0.867159
# OneLayer_750_epochs_optimized_roc_auc_score          0.952181       0.870849
# OneLayer_500_epochs_optimized_roc_auc_score          0.961409       0.845018
# ThreeLayer_250_epochs_optimized_roc_auc_score        0.989094       0.852399
# ThreeLayer_250_epochs_optimized_f1_score             0.994966       0.859779
# TwoLayer_500_epochs_optimized_roc_auc_score          0.992450       0.863469
# OneLayer_250_epochs_optimized_roc_auc_score          0.959732       0.845018
# TwoLayer_1000_epochs_optimized_f1_score              0.994966       0.870849
# OneLayer_100_epochs_optimized_roc_auc_score          0.936242       0.856089
# TwoLayer_750_epochs_optimized_recall_score           0.994966       0.863469
# ThreeLayer_100_epochs_optimized_f1_score             0.958893       0.837638
# TwoLayer_500_epochs_optimized_recall_score           0.791107       0.797048
# ThreeLayer_1000_epochs_optimized_recall_score        0.786074       0.797048
# OneLayer_1000_epochs_optimized_recall_score          0.773490       0.745387
# TwoLayer_250_epochs_optimized_recall_score           0.786074       0.797048
#
#                                                test_precision  test_recall  \
# ThreeLayer_500_epochs_optimized_roc_auc_score        0.722222     0.709091
# TwoLayer_250_epochs_optimized_roc_auc_score          0.714286     0.636364
# TwoLayer_750_epochs_optimized_roc_auc_score          0.666667     0.618182
# TwoLayer_100_epochs_optimized_roc_auc_score          0.679245     0.654545
# ThreeLayer_750_epochs_optimized_roc_auc_score        0.693878     0.618182
# OneLayer_750_epochs_optimized_roc_auc_score          0.708333     0.618182
# OneLayer_500_epochs_optimized_roc_auc_score          0.627451     0.581818
# ThreeLayer_250_epochs_optimized_roc_auc_score        0.647059     0.600000
# ThreeLayer_250_epochs_optimized_f1_score             0.666667     0.618182
# TwoLayer_500_epochs_optimized_roc_auc_score          0.680000     0.618182
# OneLayer_250_epochs_optimized_roc_auc_score          0.627451     0.581818
# TwoLayer_1000_epochs_optimized_f1_score              0.685185     0.672727
# OneLayer_100_epochs_optimized_roc_auc_score          0.642857     0.654545
# TwoLayer_750_epochs_optimized_recall_score           0.645161     0.727273
# ThreeLayer_100_epochs_optimized_f1_score             0.603774     0.581818
# TwoLayer_500_epochs_optimized_recall_score           0.500000     0.054545
# ThreeLayer_1000_epochs_optimized_recall_score        0.000000     0.000000
# OneLayer_1000_epochs_optimized_recall_score          0.208333     0.090909
# TwoLayer_250_epochs_optimized_recall_score           0.000000     0.000000
#
#                                                test_f1_score  test_auc
# ThreeLayer_500_epochs_optimized_roc_auc_score       0.715596  0.922685
# TwoLayer_250_epochs_optimized_roc_auc_score         0.673077  0.921675
# TwoLayer_750_epochs_optimized_roc_auc_score         0.641509  0.913636
# TwoLayer_100_epochs_optimized_roc_auc_score         0.666667  0.912879
# ThreeLayer_750_epochs_optimized_roc_auc_score       0.653846  0.911406
# OneLayer_750_epochs_optimized_roc_auc_score         0.660194  0.909259
# OneLayer_500_epochs_optimized_roc_auc_score         0.603774  0.900253
# ThreeLayer_250_epochs_optimized_roc_auc_score       0.622642  0.896128
# ThreeLayer_250_epochs_optimized_f1_score            0.641509  0.896002
# TwoLayer_500_epochs_optimized_roc_auc_score         0.647619  0.894697
# OneLayer_250_epochs_optimized_roc_auc_score         0.603774  0.892677
# TwoLayer_1000_epochs_optimized_f1_score             0.678899  0.889941
# OneLayer_100_epochs_optimized_roc_auc_score         0.648649  0.884933
# TwoLayer_750_epochs_optimized_recall_score          0.683761  0.884175
# ThreeLayer_100_epochs_optimized_f1_score            0.592593  0.869613
# TwoLayer_500_epochs_optimized_recall_score          0.098361  0.795118
# ThreeLayer_1000_epochs_optimized_recall_score       0.000000  0.795034
# OneLayer_1000_epochs_optimized_recall_score         0.126582  0.729209
# TwoLayer_250_epochs_optimized_recall_score          0.000000  0.722938

# %%
cols = [
    'model_class',
    'train_accuracy',
    'test_accuracy',
    'test_recall',
    'test_f1_score',
    'test_auc'
]

class_order = ['OneLayer', 'TwoLayer', 'ThreeLayer']

class_avg = performance_df[cols].groupby(['model_class']).mean()
class_avg = class_avg.loc[class_order,:]
class_avg.T.plot(kind='bar');

# %%
cols = [
    'model_class',
    'train_accuracy',
    'test_accuracy',
    'test_precision',
    'test_recall',
    'test_f1_score',
    'test_auc'
]

sns.pairplot(performance_df[cols], 
             hue='model_class', 
             hue_order=class_order,
             corner=True
            );

# %% [markdown]
# # view model predictions

# %%
import numpy as np
import pickle
import geopandas as gpd
from sklearn.preprocessing import StandardScaler
import torch
# load in the model class
from sys import path
path.append(model_dir)
import ModelNN as Net

from matplotlib import pyplot as plt
plt.style.use('seaborn-v0_8-darkgrid')

# %%
pd.set_option('display.float_format', lambda x: '%.7f' % x)

# %%
torch.cuda.device_count()
# Out:
# 0

# %%
device_0 = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device_1 = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
device_2 = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")
device_3 = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")

devices = [
    device_0,
    device_1,
    device_2,
    device_3,
]

idx = 0
device = devices[idx]
device
# Out:
# device(type='cpu')

# %%
# use whichever model name desired

#layers = 'One'
#layers = 'Two'
layers = 'Three'

compare = [
    f'{layers}Layer_250_epochs_optimized_roc_auc_score',
    f'{layers}Layer_500_epochs_optimized_roc_auc_score',
    f'{layers}Layer_750_epochs_optimized_roc_auc_score',
    
]

idx = 1

architecture = compare[idx]
one_model = model_params[architecture]
one_model
# Out:
# {'features': ['peak_i15_mmh',
#   'fire_interval',
#   'kf',
#   'SuscFrac',
#   'SAV',
#   'prophm23',
#   'SedUn'],
#  'hidden_size': 250,
#  'lr': 0.01,
#  'dropout_rate': 0.05,
#  'epochs': 500,
#  'model_class': 'ThreeLayer',
#  'weights': 'ThreeLayer_500_epochs_optimized_roc_auc_score.pth',
#  'grid_search_metric': 'roc_auc_score',
#  'performance_summary': {'train_loss': 0.020326288416981697,
#   'val_loss': 1.8640249967575073,
#   'train_accuracy': 0.9916107382550335,
#   'test_accuracy': 0.8856088560885609,
#   'test_precision': 0.7222222222222222,
#   'test_recall': 0.7090909090909091,
#   'test_f1_score': 0.7155963302752293,
#   'test_auc': 0.9226851851851852}}

# %%
performance_df.loc[compare,:].T
# Out:
#                    ThreeLayer_250_epochs_optimized_roc_auc_score  \
# hidden_size                                                  100
# lr                                                     0.0100000
# dropout_rate                                           0.1500000
# epochs                                                       250
# model_class                                           ThreeLayer
# grid_search_metric                                 roc_auc_score
# train_loss                                             0.0420898
# val_loss                                               1.1421973
# train_accuracy                                         0.9890940
# test_accuracy                                          0.8523985
# test_precision                                         0.6470588
# test_recall                                            0.6000000
# test_f1_score                                          0.6226415
# test_auc                                               0.8961279
#
#                    ThreeLayer_500_epochs_optimized_roc_auc_score  \
# hidden_size                                                  250
# lr                                                     0.0100000
# dropout_rate                                           0.0500000
# epochs                                                       500
# model_class                                           ThreeLayer
# grid_search_metric                                 roc_auc_score
# train_loss                                             0.0203263
# val_loss                                               1.8640250
# train_accuracy                                         0.9916107
# test_accuracy                                          0.8856089
# test_precision                                         0.7222222
# test_recall                                            0.7090909
# test_f1_score                                          0.7155963
# test_auc                                               0.9226852
#
#                    ThreeLayer_750_epochs_optimized_roc_auc_score
# hidden_size                                                  100
# lr                                                     0.0100000
# dropout_rate                                           0.2000000
# epochs                                                       750
# model_class                                           ThreeLayer
# grid_search_metric                                 roc_auc_score
# train_loss                                             0.0170232
# val_loss                                               1.2795470
# train_accuracy                                         0.9932886
# test_accuracy                                          0.8671587
# test_precision                                         0.6938776
# test_recall                                            0.6181818
# test_f1_score                                          0.6538462
# test_auc                                               0.9114057

# %%
# should turn this into a function


input_size = len(one_model['features'])
hidden_size = one_model['hidden_size']
dropout_rate = one_model['dropout_rate']
output_size = 1


# this is not programmatic
# it isn't getting passed in
model_class = one_model['model_class']
features = one_model['features']
# load trained model weights
weights = one_model['weights']


# instantiate model
with torch.no_grad(): # turn off gradiants for inference
    if model_class == 'OneLayer':
        model = Net.OneLayer(input_size, hidden_size, output_size, dropout_rate).to(device)
    elif model_class == 'TwoLayer':
        model = Net.TwoLayer(input_size, hidden_size, output_size, dropout_rate).to(device)
    elif model_class == 'ThreeLayer':
        model = Net.ThreeLayer(input_size, hidden_size, output_size, dropout_rate).to(device)
    model.eval() # turn off dropout etc for inference
    
# load weights
model.load_state_dict(torch.load(model_dir + weights, map_location=device))
# Out:
# <All keys matched successfully>

# %%
# LOAD IN DATA
X_train_df, X_test_df, y_train_df, y_test_df = pickle.load(open(data_dir + "train_test_data.pkl", "rb"))
X_train_df, X_test_df = X_train_df[features], X_test_df[features]

# scale on the training set
sc = StandardScaler()
X_train_scaled = pd.DataFrame(sc.fit_transform(X_train_df))
X_test_scaled = pd.DataFrame(sc.transform(X_test_df))

# could also do the whole dataset
# want to examine just the test predictions now
X_test_tensor = torch.tensor(X_test_scaled.values).float().to(device)
y_test_pred_proba = model(X_test_tensor) # already sent to device when instantiated
y_test_pred_proba = y_test_pred_proba.detach().cpu().numpy().astype(np.float16) # smaller dtype
y_test_pred_bool = np.round(y_test_pred_proba)



# additional data for full proba analysis
rain_scaler_mean = X_train_df['peak_i15_mmh'].mean()
rain_scaler_std = X_train_df['peak_i15_mmh'].std()
# now load in all the data
site_data = gpd.read_parquet(data_dir + "sites_v02_plot_data.parquet")
# need for replacing data in scaled df at inference
col_idx = site_data[features].columns.get_loc('peak_i15_mmh')
# fit the entire dataset to the scaler
X_scaled = pd.DataFrame(sc.transform(site_data[features]))

# %%
def make_prediction(df, rain_input):
    rain = pd.to_numeric(np.repeat(rain_input, df.shape[0]))
    rain_scaled = (rain - rain_scaler_mean) / rain_scaler_std
    # now replace with the scaled input
    X_scaled.loc[:,col_idx] = rain_scaled
    
    # and make prediction with the new rain amount
    X_scaled_tensor = torch.tensor(X_scaled.values).float().to(device)
    y_pred_tensor = model(X_scaled_tensor) # already sent to device when instantiated
    # predicted probability
    y_pred_proba = y_pred_tensor.detach().cpu().numpy().astype(np.float16) # smaller dtype
    # in case you want the binary output
    #y_pred_bool = np.round(y_pred_proba)
    
    return y_pred_proba

# %%
architecture
# Out:
# 'ThreeLayer_500_epochs_optimized_roc_auc_score'

# %%
sum(make_prediction(site_data, 0) == 1)
# Out:
# array([62])

# %%
# pred_df = pd.DataFrame()

# %%
# pred_df = pd.DataFrame(columns=['proba'])
col_name = 'epochs_' + str(one_model['epochs'])

for i in range(100):
    pred_df.loc[i, col_name] = make_prediction(site_data, i).mean()


#pred_df.plot(title=f'{architecture} \n Mean Proba at Rain Amts');
pred_df.plot(title=f'{model_class} Network \n Mean Proba at Rain Amts');

# %%
# pred_df

# %%
# pred_df = pd.DataFrame(columns=['proba'])
# for i in range(100):
#     pred_df.loc[i, 'proba'] = np.median(make_prediction(site_data, i))

# pred_df.plot(title=f'{architecture} \n Median Proba at Rain Amts');

# %%
# around this point it switches
pred_df.loc[45:55]
# Out:
#     epochs_250  epochs_500  epochs_750
# 45   0.6669922   0.7695312   0.2233887
# 46   0.6928711   0.7905273   0.2418213
# 47   0.7167969   0.8100586   0.2609863
# 48   0.7412109   0.8232422   0.2792969
# 49   0.7656250   0.8344727   0.2958984
# 50   0.7900391   0.8457031   0.3129883
# 51   0.8125000   0.8569336   0.3303223
# 52   0.8320312   0.8686523   0.3471680
# 53   0.8510742   0.8828125   0.3635254
# 54   0.8691406   0.8979492   0.3793945
# 55   0.8852539   0.9135742   0.3940430

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns

# %%
# bring in full file
# will need for geographic assessment of confusion matrix
file_path = "data_v08_consolidated.parquet"
df = gpd.read_parquet(data_dir + file_path)

# %%
cm = confusion_matrix(y_test_df, y_test_pred_bool)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot();
plt.title('Confusion Matrix');

# %%
# create dataframe with test values
test_assess = pd.DataFrame(y_test_df).astype(int).rename(columns={'response': 'y_test'})
# predicted values
test_assess['y_test_pred'] = y_test_pred_bool.flatten().astype(int)
# whether they are correctly predicted
test_assess['pred_correct'] = test_assess['y_test'] == test_assess['y_test_pred']
# the probability of the prediction
test_assess['y_test_pred_proba'] = y_test_pred_proba.flatten()

# precision of probas causing downstream errors
# truncate to something reasonable
test_assess['y_test_pred_proba'] = test_assess['y_test_pred_proba'].astype(str).str[:10].astype(np.float16)

# create column for confusion matrix
# we'll use this to assess the probabilities
# there's a dataframe for each of these if needed
TP = test_assess[(test_assess['y_test'] == 1) & (test_assess['pred_correct'] == True)]
FP = test_assess[(test_assess['y_test'] == 0) & (test_assess['pred_correct'] == False)]
TN = test_assess[(test_assess['y_test'] == 0) & (test_assess['pred_correct'] == True)]
FN = test_assess[(test_assess['y_test'] == 1) & (test_assess['pred_correct'] == False)]

test_assess.loc[TP.index,'confusion'] = 'TP'
test_assess.loc[FP.index,'confusion'] = 'FP'
test_assess.loc[TN.index,'confusion'] = 'TN'
test_assess.loc[FN.index,'confusion'] = 'FN'

# bring in the state values
test_assess = pd.merge(test_assess, df['state'], how='left', left_index=True, right_index=True)

test_assess
# Out:
#       y_test  y_test_pred  pred_correct  y_test_pred_proba confusion state
# 2          0            0          True          0.0000000        TN    CA
# 6          0            0          True          0.0000000        TN    CA
# 10         0            0          True          0.0000000        TN    CA
# 29         1            1          True          1.0000000        TP    ID
# 35         1            1          True          0.9965820        TP    ID
# ...      ...          ...           ...                ...       ...   ...
# 1446       0            0          True          0.0000000        TN    AZ
# 1447       0            0          True          0.0045319        TN    AZ
# 1448       0            0          True          0.0000244        TN    AZ
# 1449       0            0          True          0.0000000        TN    AZ
# 1450       0            0          True          0.0000000        TN    AZ
#
# [271 rows x 6 columns]

# %%
# overall probability distribution
test_assess['y_test_pred_proba'].hist();

# %%
test_assess.groupby(['y_test'])['y_test_pred_proba'].mean()
# Out:
# y_test
# 0   0.0794678
# 1   0.7036133
# Name: y_test_pred_proba, dtype: float16

# %%
test_assess.groupby(['y_test'])['y_test_pred_proba'].describe().T
# Out:
# y_test           0          1
# count  216.0000000 55.0000000
# mean     0.0795288  0.7036133
# std      0.2380371  0.4155273
# min      0.0000000  0.0000000
# 25%      0.0000000  0.2365723
# 50%      0.0000000  0.9956055
# 75%      0.0000256  1.0000000
# max      1.0000000  1.0000000

# %%
test_assess.groupby(['confusion'])['y_test_pred_proba'].mean()
# Out:
# confusion
# FN   0.0823364
# FP   0.8959961
# TN   0.0185547
# TP   0.9580078
# Name: y_test_pred_proba, dtype: float16

# %%
test_assess.groupby(['confusion'])['y_test_pred_proba'].describe().T.loc[:,['TP', 'FN', 'TN', 'FP']]
# Out:
# confusion         TP         FN          TN         FP
# count     39.0000000 16.0000000 201.0000000 15.0000000
# mean       0.9584961  0.0823364   0.0185547  0.8959961
# std        0.1088257  0.1068726   0.0751343  0.1488037
# min        0.5898438  0.0000000   0.0000000  0.5805664
# 25%        0.9926758  0.0000362   0.0000000  0.8244629
# 50%        1.0000000  0.0203476   0.0000000  0.9980469
# 75%        1.0000000  0.1446533   0.0000004  1.0000000
# max        1.0000000  0.3244629   0.4733887  1.0000000

# %%
# model thinks it;s certain
sum(test_assess['y_test_pred_proba'] == 1)
# Out:
# 29

# %%
# model thinks it's certain
sum(test_assess['y_test_pred_proba'] == 0)
# Out:
# 145

# %%
# records were there was actually YES debris flow
subset = ['TP', 'FN']
flows = test_assess[test_assess['confusion'].isin(subset)]

# records were there was actually NO debris flow
sub = ['TN', 'FP']
no_flows = test_assess[test_assess['confusion'].isin(sub)]

# %%
architecture
# Out:
# 'ThreeLayer_500_epochs_optimized_roc_auc_score'

# %%
# %%time
sns.displot(data=flows, x='y_test_pred_proba', hue='confusion', kde=True);
plt.ylim(0, 40); # to make sure plots are consistent when comparing
plt.title('Debris Flow: YES');
# Out:
# CPU times: user 400 ms, sys: 145 ms, total: 545 ms
# Wall time: 259 ms

# %% [markdown]
# something about the `no_flows` is really slowing up the system
# - plot not working (or at least intermittant)
# - warning about index being out of bounds
# - there must be a really small number in there
#     - truncate values?

# %%
no_flows.reset_index()
# Out:
#      index  y_test  y_test_pred  pred_correct  y_test_pred_proba confusion  \
# 0        2       0            0          True          0.0000000        TN
# 1        6       0            0          True          0.0000000        TN
# 2       10       0            0          True          0.0000000        TN
# 3       36       0            1         False          1.0000000        FP
# 4       44       0            0          True          0.0000000        TN
# ..     ...     ...          ...           ...                ...       ...
# 211   1446       0            0          True          0.0000000        TN
# 212   1447       0            0          True          0.0045319        TN
# 213   1448       0            0          True          0.0000244        TN
# 214   1449       0            0          True          0.0000000        TN
# 215   1450       0            0          True          0.0000000        TN
#
#     state
# 0      CA
# 1      CA
# 2      CA
# 3      ID
# 4      CA
# ..    ...
# 211    AZ
# 212    AZ
# 213    AZ
# 214    AZ
# 215    AZ
#
# [216 rows x 7 columns]

# %%
# %%time
# no_flows = no_flows.reset_index()
# sns.displot(data=no_flows, x='y_test_pred_proba', hue='confusion', kde=True);
# #plt.ylim(0, 750); # to make sure plots are consistent when comparing
# plt.title('Debris Flow: NO');

# %%
no_flows.shape
# Out:
# (216, 6)

# %%
# temp = no_flows.copy().reset_index(drop=True)
# temp['y_test_pred_proba'].astype(str).str[:8].astype(np.float16).astype(str).str.len().value_counts().sort_index()

# %%
# temp = no_flows.copy()
# small_mask = temp['y_test_pred_proba'].astype(str).str.len() > 7
# temp.loc[small_mask,'y_test_pred_proba'] = 0.0
# temp

# %%
# %%time
# this works sometimes???
# temp = no_flows.copy().reset_index(drop=True)
# temp['y_test_pred_proba'] = temp['y_test_pred_proba'].astype(str).str[:6].astype(np.float64)

# this works, but removes records
temp = no_flows[no_flows['y_test_pred_proba'].astype(str).str.len() < 7] # up to 8 in length

# # change the really smalls to zeros
# temp = no_flows.copy()
# small_mask = temp['y_test_pred_proba'].astype(str).str.len() > 7
# temp.loc[small_mask,'y_test_pred_proba'] = 0.0

print(no_flows.shape)
print(temp.shape)

sns.displot(data=temp, x='y_test_pred_proba', hue='confusion', kde=True);
plt.title('Debris Flow: NO');
# Out:
# (216, 6)
# (178, 6)
# CPU times: user 417 ms, sys: 113 ms, total: 530 ms
# Wall time: 250 ms

# %%
# this let's us see where are performance is coming from
# it's the percentage of each metric by state
state_matrix = test_assess.groupby(['confusion'])['state'].value_counts(normalize=True).unstack().fillna(0)#.astype(int)
state_matrix = state_matrix.loc[['TP', 'FN', 'TN', 'FP'],:]
state_matrix
# Out:
# state            AZ        CA        CO        ID        MT        NM
# confusion
# TP        0.0000000 0.8717949 0.0512821 0.0512821 0.0000000 0.0256410
# FN        0.1875000 0.4375000 0.1875000 0.0000000 0.1250000 0.0625000
# TN        0.1194030 0.5074627 0.3233831 0.0000000 0.0199005 0.0298507
# FP        0.2000000 0.4000000 0.2000000 0.0666667 0.1333333 0.0000000

# %%
# we can use this to determine
# is our confusion matrix is overindexing on certain state(s)?
state_counts = test_assess['state'].value_counts(normalize=True).sort_index()
state_counts
# Out:
# AZ   0.1107011
# CA   0.5498155
# CO   0.2693727
# ID   0.0110701
# MT   0.0295203
# NM   0.0295203
# Name: state, dtype: float64

# %%
confusion_index = state_matrix.div(state_counts) - 1
confusion_index
# Out:
# state             AZ         CA         CO         ID         MT         NM
# confusion
# TP        -1.0000000  0.5856135 -0.8096242  3.6324786 -1.0000000 -0.1314103
# FN         0.6937500 -0.2042785 -0.3039384 -1.0000000  3.2343750  1.1171875
# TN         0.0786070 -0.0770310  0.2005043 -1.0000000 -0.3258706  0.0111940
# FP         0.8066667 -0.2724832 -0.2575342  5.0222222  3.5166667 -1.0000000

# %%
confusion_index.plot(kind='barh').invert_yaxis();
plt.title('Confusion Index by State');

# %%
confusion_index
# Out:
# state             AZ         CA         CO         ID         MT         NM
# confusion
# TP        -1.0000000  0.5856135 -0.8096242  3.6324786 -1.0000000 -0.1314103
# FN         0.6937500 -0.2042785 -0.3039384 -1.0000000  3.2343750  1.1171875
# TN         0.0786070 -0.0770310  0.2005043 -1.0000000 -0.3258706  0.0111940
# FP         0.8066667 -0.2724832 -0.2575342  5.0222222  3.5166667 -1.0000000
