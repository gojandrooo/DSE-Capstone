# %% [markdown]
# ## Feature Consolidation and Split
#
# The purpose of this notebook is to consolidate a set of features, perform final null handling (some imputation), and perform a seeded train-test-split for consistency on training and comparing model performance. It also creates a JSON for hyperparameters for the ML model section to use.
#
# - [Consolidation](#consol)
# - [Null Handling](#null)
# - [Outliers](#out)
# - [Train-Test Split](#split)
#     - *standard scaler applied in modeling notebooks*

# %%
# assign seed now for consistency any time it needs to be used
seed=27

# %%
import pandas as pd
import geopandas as gpd
#import numpy as np
from sklearn.model_selection import train_test_split
#from sklearn.preprocessing import StandardScaler
import pickle

# %%
file_path = "../../data/data_v07_fire_interval.parquet"
df = gpd.read_parquet(file_path)
print('raw data: ',df.shape)
df
# Out:
# raw data:  (1550, 52)
#      fire_name  year fire_id fire_segid  database state  response   stormdate  \
# 0     Buckweed  2007     bck   bck_1035  Training    CA         0  2008-01-22
# 1     Buckweed  2007     bck   bck_1090  Training    CA         0  2008-01-22
# 2     Buckweed  2007     bck   bck_1570  Training    CA         0  2008-01-22
# 3     Buckweed  2007     bck    bck_235  Training    CA         0  2008-01-22
# 4     Buckweed  2007     bck    bck_363  Training    CA         0  2008-01-22
# ...        ...   ...     ...        ...       ...   ...       ...         ...
# 1545    Wallow  2011     wlw  wlw_47409      Test    AZ         0  2011-09-07
# 1546    Wallow  2011     wlw  wlw_47535      Test    AZ         0  2011-07-11
# 1547    Wallow  2011     wlw  wlw_47535      Test    AZ         0  2011-07-26
# 1548    Wallow  2011     wlw  wlw_47535      Test    AZ         0  2011-08-15
# 1549    Wallow  2011     wlw  wlw_47535      Test    AZ         0  2011-09-07
#
#       gaugedist_m          stormstart  ... Sedimentary  Unconsolidated  \
# 0         1998.67 2008-01-21 16:27:00  ...    0.000000             0.0
# 1         2368.93 2008-01-21 16:27:00  ...    0.000000             0.0
# 2         3956.74 2008-01-21 16:27:00  ...    0.026753             0.0
# 3         1734.72 2008-01-21 15:47:00  ...    0.000000             0.0
# 4         1801.04 2008-01-21 15:47:00  ...    0.000000             0.0
# ...           ...                 ...  ...         ...             ...
# 1545      2706.25 2011-09-07 15:00:00  ...    0.000000             0.0
# 1546      2891.75 2011-07-11 14:45:00  ...    0.000000             0.0
# 1547      2891.75 2011-07-26 10:45:00  ...    0.000000             0.0
# 1548      2891.75 2011-08-15 11:00:00  ...    0.000000             0.0
# 1549      2891.75 2011-09-07 15:00:00  ...    0.000000             0.0
#
#             domrt  age_min  age_max  index_right     LNDS_RISKV  LNDS_RISKS  \
# 0     Metamorphic     56.0     72.1          205  380675.353544   96.305814
# 1     Metamorphic     56.0     72.1          205  380675.353544   96.305814
# 2     Metamorphic     56.0     72.1          205  380675.353544   96.305814
# 3     Metamorphic     56.0     72.1          205  380675.353544   96.305814
# 4     Metamorphic     56.0     72.1          205  380675.353544   96.305814
# ...           ...      ...      ...          ...            ...         ...
# 1545      Igneous      NaN      NaN          102  245876.108811   94.282043
# 1546      Igneous      NaN      NaN          102  245876.108811   94.282043
# 1547      Igneous      NaN      NaN          102  245876.108811   94.282043
# 1548      Igneous      NaN      NaN          102  245876.108811   94.282043
# 1549      Igneous      NaN      NaN          102  245876.108811   94.282043
#
#                LNDS_RISKR  fire_interval
# 0         Relatively High             -1
# 1         Relatively High             -1
# 2         Relatively High             -1
# 3         Relatively High             -1
# 4         Relatively High             -1
# ...                   ...            ...
# 1545  Relatively Moderate              0
# 1546  Relatively Moderate              0
# 1547  Relatively Moderate              0
# 1548  Relatively Moderate              0
# 1549  Relatively Moderate              0
#
# [1550 rows x 52 columns]

# %%
import seaborn as sns

# %%
cols = [
    'response',
    'stormaccum_mm', 
    'stormavgi_mmh', 
    'peak_i15_mmh', 
]

sns.pairplot(df[cols], 
             hue='response', 
             corner=True);

# %% [markdown]
# ## Feature Consolidation <a id="consol">

# %% [markdown]
# Sedimentary and Unconsolidated rocks have similar debris flow occurrences.
#
# Define additional features:
# -  `SedUn`: fraction of watershed covered by sedimentary and unconsolidated rocks.
# - `SuscFrac`: fraction of watershed covered by susceptible vegetation types (everything except grassland, `GR`

# %%
df["SedUn"] = df["Sedimentary"] + df["Unconsolidated"]
df["SuscFrac"] = df["GS"] + df["SH"] + df["TL"] + df["TU"]

# %%
use_cols = [
    'SiteID', # will ultimately be needed for joining    
    'fire_id',
    'fire_name',
    'fire_segid',
    'year',
    'state',
    #'database', # original staley train/test
    'response',
    'stormdate',
    'gaugedist_m',
    'lat',
    'lon',
    'geom',
    'geometry',
]

# %%
feature_cols = [
    'peak_i15_mmh',
    # 'peak_i30_mmh', 
    # 'peak_i60_mmh', 
    'contributingarea_km2', 
    'prophm23',
    'dnbr1000', 
    'kf', 
    #'acc015_mm', 
    # 'acc030_mm', 
    # 'acc060_mm', 
    'Fine fuel load', 
    'SAV', 
    'Packing ratio', 
    'Extinction moisture content',
    'LNDS_RISKS',
    'fire_interval',
    'SedUn',
    'SuscFrac',
]

# %%
use_cols + feature_cols
# Out:
# ['SiteID',
#  'fire_id',
#  'fire_name',
#  'fire_segid',
#  'year',
#  'state',
#  'response',
#  'stormdate',
#  'gaugedist_m',
#  'lat',
#  'lon',
#  'geom',
#  'geometry',
#  'peak_i15_mmh',
#  'contributingarea_km2',
#  'prophm23',
#  'dnbr1000',
#  'kf',
#  'Fine fuel load',
#  'SAV',
#  'Packing ratio',
#  'Extinction moisture content',
#  'LNDS_RISKS',
#  'fire_interval',
#  'SedUn',
#  'SuscFrac']

# %%
df = df[use_cols + feature_cols]
df
# Out:
#       SiteID fire_id fire_name fire_segid  year state  response   stormdate  \
# 0          0     bck  Buckweed   bck_1035  2007    CA         0  2008-01-22
# 1          1     bck  Buckweed   bck_1090  2007    CA         0  2008-01-22
# 2          2     bck  Buckweed   bck_1570  2007    CA         0  2008-01-22
# 3          3     bck  Buckweed    bck_235  2007    CA         0  2008-01-22
# 4          4     bck  Buckweed    bck_363  2007    CA         0  2008-01-22
# ...      ...     ...       ...        ...   ...   ...       ...         ...
# 1545     714     wlw    Wallow  wlw_47409  2011    AZ         0  2011-09-07
# 1546     715     wlw    Wallow  wlw_47535  2011    AZ         0  2011-07-11
# 1547     715     wlw    Wallow  wlw_47535  2011    AZ         0  2011-07-26
# 1548     715     wlw    Wallow  wlw_47535  2011    AZ         0  2011-08-15
# 1549     715     wlw    Wallow  wlw_47535  2011    AZ         0  2011-09-07
#
#       gaugedist_m        lat  ...  dnbr1000        kf Fine fuel load  \
# 0         1998.67  34.542358  ...  0.297853  0.250000       1.808258
# 1         2368.93  34.540093  ...  0.224896  0.250000       1.384151
# 2         3956.74  34.528844  ...  0.065537  0.248541       1.599649
# 3         1734.72  34.558602  ...  0.141711  0.250000       1.775339
# 4         1801.04  34.554817  ...  0.210158  0.250000       1.847506
# ...           ...        ...  ...       ...       ...            ...
# 1545      2706.25  33.654978  ...  0.187053  0.000000       0.985050
# 1546      2891.75  33.653975  ...  0.500223  0.000000       1.831648
# 1547      2891.75  33.653975  ...  0.500223  0.000000       1.831648
# 1548      2891.75  33.653975  ...  0.500223  0.000000       1.831648
# 1549      2891.75  33.653975  ...  0.500223  0.000000       1.831648
#
#               SAV  Packing ratio  Extinction moisture content  LNDS_RISKS  \
# 0     1818.146903       0.002187                    15.000000   96.305814
# 1     1821.989060       0.001839                    15.000000   96.305814
# 2     1816.939332       0.002439                    15.099213   96.305814
# 3     1817.801690       0.002657                    15.093254   96.305814
# 4     1816.320840       0.002579                    15.092942   96.305814
# ...           ...            ...                          ...         ...
# 1545  1616.534444       0.018070                    19.422728   94.282043
# 1546  1709.367304       0.012261                    18.278098   94.282043
# 1547  1709.367304       0.012261                    18.278098   94.282043
# 1548  1709.367304       0.012261                    18.278098   94.282043
# 1549  1709.367304       0.012261                    18.278098   94.282043
#
#       fire_interval     SedUn  SuscFrac
# 0                -1  0.000000  0.656167
# 1                -1  0.000000  0.271910
# 2                -1  0.026753  0.487114
# 3                -1  0.000000  0.678739
# 4                -1  0.000000  0.696387
# ...             ...       ...       ...
# 1545              0  0.000000  0.822226
# 1546              0  0.000000  0.971051
# 1547              0  0.000000  0.971051
# 1548              0  0.000000  0.971051
# 1549              0  0.000000  0.971051
#
# [1550 rows x 26 columns]

# %% [markdown]
# ## Handle Nulls <a id="null">
#
# - finally dealing with null values since we have aggregated our data and settled on possible feature set and

# %%
nan_count = pd.DataFrame(df.isna().sum(), columns=['count'])
nan_count = nan_count[nan_count['count'] > 0]

nan_cols = list(nan_count.index)

nan_count
# Out:
#                              count
# peak_i15_mmh                   230
# dnbr1000                        77
# Fine fuel load                   3
# SAV                              3
# Packing ratio                    3
# Extinction moisture content      3

# %%
idx = 2
col = nan_cols[idx]
print(col)

# to get summary of nan count
#df[df[col].isna()].isna().sum()

# to view the df
df[df[col].isna()]
# Out:
# Fine fuel load
#      SiteID fire_id  fire_name fire_segid  year state  response   stormdate  \
# 269     130      cs  Coal Seam     cs_813  2002    CO         0  2002-08-05
# 270     130      cs  Coal Seam     cs_813  2002    CO         0  2002-09-11
# 271     130      cs  Coal Seam     cs_813  2002    CO         0  2002-09-12
#
#      gaugedist_m        lat  ...  dnbr1000    kf Fine fuel load  SAV  \
# 269      2154.77  39.558541  ...   0.26645  0.33            NaN  NaN
# 270      2825.70  39.558541  ...   0.26645  0.33            NaN  NaN
# 271      2825.70  39.558541  ...   0.26645  0.33            NaN  NaN
#
#      Packing ratio  Extinction moisture content  LNDS_RISKS  fire_interval  \
# 269            NaN                          NaN   98.939929              0
# 270            NaN                          NaN   98.939929              0
# 271            NaN                          NaN   98.939929              0
#
#      SedUn  SuscFrac
# 269    1.0       0.0
# 270    1.0       0.0
# 271    1.0       0.0
#
# [3 rows x 26 columns]

# %% [markdown]
# right off the bat, three records all share the same NaNs, drop these sites
#
# - Fine fuel load
# - SAV
# - Packing ratio
# - Extinction moisture content
#
# ![image.png](attachment:40ac6903-5518-4837-b4c4-e478ef2c684a.png)

# %%
# picking easiest one to type :)
# any of the other three would be fine
df = df.dropna(subset=['SAV'])
df.shape
# Out:
# (1547, 26)

# %% [markdown]
# **dnbr1000**: *Average differenced normalized burn ratio (dNBR) of watershed, divided by 1000*
# - recorded with satellite imagery before/after fire
# - they could be na simply because the number is actually zero
# - it may make sense to fill some of these values with zer0, but we just don't know
# - most of them probably weren't recorded due to nature of capturing this
#     - best to drop these

# %%
nan_count = pd.DataFrame(df.isna().sum(), columns=['count'])
nan_count = nan_count[nan_count['count'] > 0]

nan_cols = list(nan_count.index)

nan_count
# Out:
#               count
# peak_i15_mmh    229
# dnbr1000         77

# %%
idx = 1
col = nan_cols[idx]
print(col)

# to get summary of nan count
#df[df[col].isna()].isna().sum()

# to view the df
df[df[col].isna()]#['response'].value_counts()
# Out:
# dnbr1000
#      SiteID fire_id    fire_name fire_segid  year state  response   stormdate  \
# 42       37     can       Canyon    can_178  2007    CA         0  2008-01-22
# 51       46     can       Canyon    can_558  2007    CA         0  2008-01-22
# 468     257     h2f  Horseshoe 2  h2f_10214  2001    AZ         0  2011-07-11
# 469     257     h2f  Horseshoe 2  h2f_10214  2001    AZ         0  2011-08-11
# 470     257     h2f  Horseshoe 2  h2f_10214  2001    AZ         0  2011-08-13
# ..      ...     ...          ...        ...   ...   ...       ...         ...
# 805     395     scz      Schultz    scz_792  2010    AZ         1  2010-07-20
# 806     395     scz      Schultz    scz_792  2010    AZ         0  2010-07-22
# 807     395     scz      Schultz    scz_792  2010    AZ         0  2010-07-27
# 808     395     scz      Schultz    scz_792  2010    AZ         0  2010-08-01
# 809     395     scz      Schultz    scz_792  2010    AZ         0  2010-08-16
#
#      gaugedist_m        lat  ...  dnbr1000        kf Fine fuel load  \
# 42       1685.96  34.058303  ...       NaN  0.210000       1.460550
# 51       1127.42  34.037234  ...       NaN  0.210000       1.372025
# 468      3729.34  31.937136  ...       NaN  0.387281       3.131857
# 469      3729.34  31.937136  ...       NaN  0.387281       3.131857
# 470      3729.34  31.937136  ...       NaN  0.387281       3.131857
# ..           ...        ...  ...       ...       ...            ...
# 805      2238.05  35.348953  ...       NaN  0.337403       1.564575
# 806      2238.05  35.348953  ...       NaN  0.337403       1.564575
# 807      2238.05  35.348953  ...       NaN  0.337403       1.564575
# 808      2238.05  35.348953  ...       NaN  0.337403       1.564575
# 809      2238.05  35.348953  ...       NaN  0.337403       1.564575
#
#              SAV  Packing ratio  Extinction moisture content  LNDS_RISKS  \
# 42   1727.041284       0.010079                    18.853211   96.305814
# 51   1834.153075       0.003318                    15.240642   96.305814
# 468  1639.596448       0.028991                    26.797437   76.774815
# 469  1639.596448       0.028991                    26.797437   76.774815
# 470  1639.596448       0.028991                    26.797437   76.774815
# ..           ...            ...                          ...         ...
# 805  1792.639022       0.004912                    16.353771   97.462255
# 806  1792.639022       0.004912                    16.353771   97.462255
# 807  1792.639022       0.004912                    16.353771   97.462255
# 808  1792.639022       0.004912                    16.353771   97.462255
# 809  1792.639022       0.004912                    16.353771   97.462255
#
#      fire_interval  SedUn  SuscFrac
# 42              -1    1.0  0.977064
# 51              -1    1.0  0.662182
# 468            -10    0.0  1.000000
# 469            -10    0.0  1.000000
# 470            -10    0.0  1.000000
# ..             ...    ...       ...
# 805              0    0.0  0.225601
# 806              0    0.0  0.225601
# 807              0    0.0  0.225601
# 808              0    0.0  0.225601
# 809              0    0.0  0.225601
#
# [77 rows x 26 columns]

# %%
temp = df[df['dnbr1000'].isna()]
print("n_sites: ", temp['SiteID'].nunique())
temp.groupby(['SiteID'])['response'].value_counts().unstack().fillna(0).astype(int)
# Out:
# n_sites:  18
# response  0  1
# SiteID
# 37        1  0
# 46        1  0
# 257       4  0
# 258       4  0
# 259       3  1
# 260       4  0
# 261       3  1
# 262       3  1
# 263       5  1
# 377       4  1
# 379       3  2
# 387       3  2
# 389       3  2
# 390       3  2
# 392       3  2
# 393       4  1
# 394       4  1
# 395       4  1

# %%
temp.groupby(['state'])['response'].value_counts(normalize=True).unstack().fillna(0)#.astype(int)
# Out:
# response     0     1
# state
# AZ        0.76  0.24
# CA        1.00  0.00

# %%
df.groupby(['state'])['response'].value_counts(normalize=True).unstack().fillna(0)#.astype(int)
# Out:
# response         0         1
# state
# AZ        0.803828  0.196172
# CA        0.785942  0.214058
# CO        0.882155  0.117845
# ID        0.214286  0.785714
# MT        0.730769  0.269231
# NM        0.396552  0.603448
# UT        0.000000  1.000000

# %%
df[df['state'] == 'UT'][['lat', 'lon']]
# Out:
#            lat         lon
# 617  39.981119 -111.760945
# 618  39.976136 -111.761739
# 619  39.966260 -111.756419
# 620  39.956666 -111.759679

# %%
df['dnbr1000'].describe()
# Out:
# count    1470.000000
# mean        0.340469
# std         0.189550
# min         0.007158
# 25%         0.192521
# 50%         0.312599
# 75%         0.461608
# max         0.997439
# Name: dnbr1000, dtype: float64

# %%
df['dnbr1000'].hist();

# %%
df.groupby(['response'])['dnbr1000'].describe().T
# Out:
# response            0           1
# count     1154.000000  316.000000
# mean         0.331684    0.372549
# std          0.193312    0.171626
# min          0.007158    0.039175
# 25%          0.184506    0.234884
# 50%          0.296068    0.381477
# 75%          0.448531    0.496389
# max          0.997439    0.867421

# %%
import seaborn as sns

# %%
sns.displot(data=df, x='dnbr1000', hue='response', kde='True');

# %% [markdown]
# **DROP THEM**

# %%
# drop the nulls
df = df.dropna(subset=['dnbr1000'])
df.shape
# Out:
# (1470, 26)

# %% [markdown]
# **now the big one, rain!**
#
# none of these records have a recorded debris flow
# - strong indication there simply wasn't a rain storm
# - additionally none of the other features for this subset are null

# %%
nan_count = pd.DataFrame(df.isna().sum(), columns=['count'])
nan_count = nan_count[nan_count['count'] > 0]

nan_cols = list(nan_count.index)

nan_count
# Out:
#               count
# peak_i15_mmh    229

# %%
idx = 0
col = nan_cols[idx]
print(col)

# to get summary of nan count
df[df[col].isna()].isna().sum()

# to view the df
#df[df[col].isna()]['response'].value_counts()
# Out:
# peak_i15_mmh
# SiteID                           0
# fire_id                          0
# fire_name                        0
# fire_segid                       0
# year                             0
# state                            0
# response                         0
# stormdate                        0
# gaugedist_m                      0
# lat                              0
# lon                              0
# geom                             0
# geometry                         0
# peak_i15_mmh                   229
# contributingarea_km2             0
# prophm23                         0
# dnbr1000                         0
# kf                               0
# Fine fuel load                   0
# SAV                              0
# Packing ratio                    0
# Extinction moisture content      0
# LNDS_RISKS                       0
# fire_interval                    0
# SedUn                            0
# SuscFrac                         0
# dtype: int64

# %% [markdown]
# **FILL NA*

# %%
# these should all be set to zer0
df['peak_i15_mmh'] = df['peak_i15_mmh'].fillna(0)
df.shape
# Out:
# (1470, 26)

# %%
df.isna().sum()
# Out:
# SiteID                         0
# fire_id                        0
# fire_name                      0
# fire_segid                     0
# year                           0
# state                          0
# response                       0
# stormdate                      0
# gaugedist_m                    0
# lat                            0
# lon                            0
# geom                           0
# geometry                       0
# peak_i15_mmh                   0
# contributingarea_km2           0
# prophm23                       0
# dnbr1000                       0
# kf                             0
# Fine fuel load                 0
# SAV                            0
# Packing ratio                  0
# Extinction moisture content    0
# LNDS_RISKS                     0
# fire_interval                  0
# SedUn                          0
# SuscFrac                       0
# dtype: int64

# %% [markdown]
# # Outliers <a id="out">

# %% [markdown]
# **KF**: *Average KF-Factor (erodibility index of the fine fragments of the soil) of the watershed*
#
# there are a couple outlandish values, should filter them

# %%
df['kf'].describe()
# Out:
# count    1470.000000
# mean        0.232062
# std         0.436961
# min         0.000000
# 25%         0.150000
# 50%         0.237299
# 75%         0.247909
# max        11.360418
# Name: kf, dtype: float64

# %%
df['kf'].describe()
# Out:
# count    1470.000000
# mean        0.232062
# std         0.436961
# min         0.000000
# 25%         0.150000
# 50%         0.237299
# 75%         0.247909
# max        11.360418
# Name: kf, dtype: float64

# %%
df['kf'].hist();

# %%
# you can see these values are waaaaay above the rest of the data (outliers)
df[df['kf'] > .39]#.shape
# Out:
#      SiteID fire_id     fire_name fire_segid  year state  response  \
# 64       59      cg  Cerro Grande    cg_2811  2000    NM         0
# 571     295      lb   Little Bear    lb_1869  2012    NM         1
# 572     295      lb   Little Bear    lb_1869  2012    NM         1
# 575     297      lb   Little Bear    lb_1930  2012    NM         1
# 576     297      lb   Little Bear    lb_1930  2012    NM         1
# 583     301      lb   Little Bear    lb_2076  2012    NM         1
# 584     301      lb   Little Bear    lb_2076  2012    NM         1
#
#       stormdate  gaugedist_m        lat  ...  dnbr1000         kf  \
# 64   2000-07-16   576.986342  35.905976  ...  0.866541   0.979461
# 571  2013-07-10   637.514953  33.457880  ...  0.258807   3.547535
# 572  2013-07-23   637.514953  33.457880  ...  0.258807   3.547535
# 575  2013-07-10  1401.780000  33.457195  ...  0.361525   0.536829
# 576  2013-07-23  1401.780000  33.457195  ...  0.361525   0.536829
# 583  2013-07-10  1037.460000  33.454449  ...  0.508008  11.360418
# 584  2013-07-23  1037.460000  33.454449  ...  0.508008  11.360418
#
#     Fine fuel load          SAV  Packing ratio  Extinction moisture content  \
# 64        2.639095  1708.904303       0.003062                    15.469214
# 571       6.021280  1434.442907       0.024328                    26.756055
# 572       6.021280  1434.442907       0.024328                    26.756055
# 575       4.148664  1791.450070       0.023591                    26.336146
# 576       4.148664  1791.450070       0.023591                    26.336146
# 583       4.232764  1517.885968       0.019444                    23.918078
# 584       4.232764  1517.885968       0.019444                    23.918078
#
#      LNDS_RISKS  fire_interval  SedUn  SuscFrac
# 64    16.672021              0    0.0  0.622404
# 571   54.706071             -1    0.0  0.986348
# 572   54.706071             -1    0.0  0.986348
# 575   54.706071             -1    0.0  1.000000
# 576   54.706071             -1    0.0  1.000000
# 583   54.706071             -1    0.0  0.917497
# 584   54.706071             -1    0.0  0.917497
#
# [7 rows x 26 columns]

# %%
df[df['kf'] > .39]['response'].value_counts()
# Out:
# 1    6
# 0    1
# Name: response, dtype: int64

# %%
print("before removal: ", df.shape)
outlier_mask = df['kf'] <= .39
df = df.loc[outlier_mask,:]
print("after removal: ", df.shape)
# Out:
# before removal:  (1470, 26)
# after removal:  (1463, 26)

# %% [markdown]
# **save the file**

# %%
# final step, reset index, just good practice
df = df.reset_index(drop=True)
df.shape
# Out:
# (1463, 26)

# %%
# one last check :)
df.isna().sum()
# Out:
# SiteID                         0
# fire_id                        0
# fire_name                      0
# fire_segid                     0
# year                           0
# state                          0
# response                       0
# stormdate                      0
# gaugedist_m                    0
# lat                            0
# lon                            0
# geom                           0
# geometry                       0
# peak_i15_mmh                   0
# contributingarea_km2           0
# prophm23                       0
# dnbr1000                       0
# kf                             0
# Fine fuel load                 0
# SAV                            0
# Packing ratio                  0
# Extinction moisture content    0
# LNDS_RISKS                     0
# fire_interval                  0
# SedUn                          0
# SuscFrac                       0
# dtype: int64

# %%
df['state'].value_counts()
# Out:
# CA    937
# CO    297
# AZ    134
# NM     51
# MT     26
# ID     14
# UT      4
# Name: state, dtype: int64

# %%
df.groupby(['state'])['response'].value_counts().unstack().fillna(0).astype(int)
# Out:
# response    0    1
# state
# AZ        111   23
# CA        736  201
# CO        262   35
# ID          3   11
# MT         19    7
# NM         22   29
# UT          0    4

# %%
# now write out the final data file
df.to_parquet("../../data/data_v08_consolidated.parquet")

# %% [markdown]
# ## Train-Test Split <a id="split">

# %% [markdown]
# Data rows are split by SiteID, such that observations made at same site (during different storms) are not assigned to the both the test and training set.
# The `unique` attribute is, therefore, essential - otherwise the split of train and test data by site is not guaranteed.

# %%
# changing seed number from all of our other notebooks
# this gives a better train-test-split on response variable
seed=42

# %%
train_sites, test_sites = train_test_split(df['SiteID'].unique(), test_size=0.20, shuffle=True, random_state=seed)

# %%
# no overlap
set(train_sites).intersection(set(test_sites))
# Out:
# set()

# %%
# how to retain the non-feature/response cols
# could join back in later? think through this

train_mask = df['SiteID'].isin(train_sites)
test_mask = df['SiteID'].isin(test_sites)

# %%
X_train = df.loc[train_mask, feature_cols]
X_test = df.loc[test_mask, feature_cols]

y_train = df.loc[train_mask, 'response']
y_test = df.loc[test_mask, 'response']

# %%
print("X_train: ", X_train.shape)
print("X_test: ", X_test.shape)
print("\n")
print("y_train: ", y_train.shape)
print("y_test: ", y_test.shape)
# Out:
# X_train:  (1192, 13)
# X_test:  (271, 13)
#
#
# y_train:  (1192,)
# y_test:  (271,)

# %%
y_train.value_counts(normalize=True)
# Out:
# 0    0.786074
# 1    0.213926
# Name: response, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# 0    0.797048
# 1    0.202952
# Name: response, dtype: float64

# %%
pickle.dump([X_train, X_test, y_train, y_test], open("../../data/train_test_data.pkl", "wb"))
